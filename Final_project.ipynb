# %% [markdown]
# # Mount google drive to colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the dataset

# %%
import pandas as pd

file_path = '/content/drive/My Drive/Colab Notebooks/Datasets/Popular_Spotify_Songs.csv'

try:
  df = pd.read_csv(file_path, encoding='utf-8')
except UnicodeDecodeError:
  df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %% [markdown]
# # Explore the dataset

# %%
# show number of rows and columns
df.shape
# Out:
# (953, 24)

# %%
# show first five rows
df.head(5)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# show last five rows
df.tail(5)
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# show data types
df.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                 object
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts        object
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
# summary statistics
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
# number of missing values if any
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# ## Visualizing the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# bar plot
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.barplot(x='released_year', y='in_spotify_playlists', data=df, estimator=sum, ci=None, palette='viridis')
plt.xlabel('Release Year')
plt.ylabel('Spotify Playlists')
plt.title('Spotify Playlists by Release Year')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-15-2f6968702849>:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='released_year', y='in_spotify_playlists', data=df, estimator=sum, ci=None, palette='viridis')
# <ipython-input-15-2f6968702849>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='released_year', y='in_spotify_playlists', data=df, estimator=sum, ci=None, palette='viridis')

# %% [markdown]
# The bar plot above shows the average number of spotify playlist songs in each release year

# %%
# bar plot
sns.set(style="whitegrid")

plt.figure(figsize=(12, 6))
sns.barplot(x='released_year', y='in_apple_playlists', data=df, estimator=sum, ci=None, palette='viridis')
plt.xlabel('Release Year')
plt.ylabel('Apple Playlists')
plt.title('Apple Playlists by Release Year')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-16-82df956629d4>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='released_year', y='in_apple_playlists', data=df, estimator=sum, ci=None, palette='viridis')
# <ipython-input-16-82df956629d4>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='released_year', y='in_apple_playlists', data=df, estimator=sum, ci=None, palette='viridis')

# %% [markdown]
# The bar plot above shows the average number of apple playlists songs in each release year

# %%
# group by artist and find the mean danceability for each artist
artist_danceability = df.groupby('artist(s)_name')['danceability_%'].mean().reset_index()

# sort artists by danceability in descending order and take top 10
top_artists_danceability = artist_danceability.sort_values(by='danceability_%', ascending=False).head(10)

# set plot style
sns.set(style="whitegrid")

# bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='danceability_%', y='artist(s)_name', data=top_artists_danceability, palette='viridis')
plt.xlabel('Danceability (%)')
plt.ylabel('Artist(s) Name')
plt.title('Top 10 Artists with the Most Danceable Songs')
plt.show()
# Out:
# <ipython-input-17-11064ce1c896>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='danceability_%', y='artist(s)_name', data=top_artists_danceability, palette='viridis')

# %% [markdown]
# The bar plot above shows the artists names and how danceable their songs are

# %% [markdown]
# # Features and target

# %%
# identify and set feature and target columns
target_column = 'streams'
feature_columns = ['track_name', 'artist(s)_name', 'artist_count', 'released_year', 'released_month', 'released_day', 'in_spotify_playlists',
                   'in_spotify_charts', 'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
                   'key', 'mode', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']

# drop rows with missing target values
df = df.dropna(subset=[target_column])

# %%
from sklearn.model_selection import train_test_split

# split the data into features and target
x = df[feature_columns]
y = df[target_column]

# %%
# verify splitting
print("Features shape:", x.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (953, 23)
# Target shape: (953,)

# %% [markdown]
# # Handle non-numeric columns

# %%
from sklearn.preprocessing import OneHotEncoder

# apply one-hot encoding to categorical columns
x_encoded = pd.get_dummies(x, columns=['track_name', 'artist(s)_name', 'key', 'mode'])

# display the shape after encoding
print("Encoded Features shape:", x_encoded.shape)
# Out:
# Encoded Features shape: (953, 1620)

# %% [markdown]
# # Split the data

# %%
# split into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_encoded, y, test_size=0.2, random_state=42)

# %%
# check shapes of the splits
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (762, 1620)
# y_train shape: (762,)
# x_test shape: (191, 1620)
# y_test shape: (191,)

# %% [markdown]
# # Build neural network model

# %% [markdown]
# Neural network model was chosen because it is highly flexible and can capture complex relationships

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# define the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1))

# compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 64)                103744
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 1)                 17
#
# ...
# Total params: 106369 (415.50 KB)
# Trainable params: 106369 (415.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Model training

# %%
# train the model and save the training history
history = model.fit(x_train, y_train, epochs=15, batch_size=10, verbose=1, validation_split=0.2)

# plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Progress During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-c973173b1e6c> in <cell line: 2>()
#       1 # Train the model and save the training history
# ----> 2 history = model.fit(x_train, y_train, epochs=15, batch_size=10, verbose=1, validation_split=0.2)
#       3
#       4 # Plot training & validation loss values
#       5 plt.figure(figsize=(10, 6))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
# ...

# %% [markdown]
# # Model evaluation

# %%
loss = model.evaluate(x_test, y_test,verbose=0)
print(f"Test Loss: {loss}")

# %%
# predictions
predictions = model.predict(x_test)
predictions
